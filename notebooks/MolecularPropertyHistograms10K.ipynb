# %%
from deepchem.utils.save import load_from_disk
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
###Display logD histogram
dataset_file= "./enamineSubset10KGroundTruth.csv"
train_dataset_file= "./lipophilicity.csv"

dataset = load_from_disk(dataset_file)
train_dataset = load_from_disk(train_dataset_file)

logDs = np.array(dataset["logD"])
train_logDs = np.array(train_dataset["exp"])

n, bins, patches = plt.hist(logDs, 50, facecolor='green', alpha=.5, label="REAL", density=True)
n, bins, patches = plt.hist(train_logDs, 50, facecolor='blue', alpha=0.5, label="TRAIN", density=True)

plt.xlabel('Ground truth train and predicted logD')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of train and GT predicted logDs')
plt.grid(True)
plt.legend()
plt.yticks([])
plt.show()

# %%
###Display logD histogram for both subsets
dataset_file= "./enamineSubset10KGroundTruth_3.csv"
hundredK_file = "./enamineSubset10KGroundTruth_2.csv"
#train_dataset_file= "./lipophilicity.csv"
train_dataset_file= "./enamineSubset10KGroundTruth.csv"
fourth = "./enamineSubset10KGroundTruth_4.csv"

dataset10 = load_from_disk(dataset_file)
dataset100 = load_from_disk(hundredK_file)
train_dataset = load_from_disk(train_dataset_file)
fourth_dataset = load_from_disk(fourth)

logDs10 = np.array(dataset10["logD"])
logDs100 = np.array(dataset100["logD"])
#train_logDs = np.array(train_dataset["exp"])
train_logDs = np.array(train_dataset["logD"])
fourth_logDs = np.array(fourth_dataset["logD"])

plt.hist(logDs10, 50, facecolor='green', alpha=.3, label="10K Enamine Subset 3", density=True)
plt.hist(logDs100, 50, facecolor='red', alpha=.3, label="10K Enamine Subset 2", density=True)
plt.hist(train_logDs, 50, facecolor='blue', alpha=.3, label="10K Enamine Subset 1", density=True)
plt.hist(fourth_logDs, 50, facecolor='orange', alpha=.5, label="10K Enamine Subset 4", density=True)

plt.xlabel('Partition coefficient logD')
plt.ylabel('Number of compounds')
plt.title(r'Training and ground truth model predicted logDs')
plt.grid(True)
plt.legend()
plt.yticks([])
plt.show()

# %%
###Display ESOL histogram
dataset_file= "./enamineSubset10KGroundTruth.csv"
train_dataset_file= "./esol.csv"

dataset = load_from_disk(dataset_file)
train_dataset = load_from_disk(train_dataset_file)

esol = np.array(dataset["esol"])
train_esol = np.array(train_dataset["measured log solubility in mols per litre"])

n, bins, patches = plt.hist(esol, 50, facecolor='green', alpha=0.5, label="REAL", density=True)
n, bins, patches = plt.hist(train_esol, 50, facecolor='blue', alpha=0.5, label="TRAIN", density=True)

plt.xlabel('Ground truth predicted and train ESOL')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of predicted and train ESOLs')
plt.grid(True)
plt.legend()
plt.yticks([])
plt.show()

# %%
###Display ESOL histogram for both subsets
dataset_file= "./enamineSubset10KGroundTruth_3.csv"
#train_dataset_file= "./esol.csv"
train_dataset_file= "./enamineSubset10KGroundTruth_2.csv"
hundredK_file = "./enamineSubset100KGroundTruth.csv"
fourth = "./enamineSubset10KGroundTruth_4.csv"

dataset10 = load_from_disk(dataset_file)
dataset100 = load_from_disk(hundredK_file)
train_dataset = load_from_disk(train_dataset_file)
fourth_dataset = load_from_disk(fourth)

esol10 = np.array(dataset10["esol"])
esol100 = np.array(dataset100["esol"])
#train_esol = np.array(train_dataset["measured log solubility in mols per litre"])
train_esol = np.array(train_dataset["esol"])
fourth_esol = np.array(fourth_dataset["esol"])

plt.hist(esol10, 50, facecolor='green', alpha=0.5, label="10K Enamine Subset 3", density=True)
plt.hist(esol100, 50, facecolor='red', alpha=0.5, label="100K Enamine Subset 1", density=True)
plt.hist(train_esol, 50, facecolor='blue', alpha=0.5, label="10K Enamine Subset 2", density=True)
plt.hist(fourth_esol, 50, facecolor='orange', alpha=.5, label="10K Enamine Subset 4", density=True)

plt.xlabel('Log of solubility(mol/L)')
plt.ylabel('Number of compounds')
plt.title(r'Training and ground truth model predicted ESOLs')
plt.grid(True)
plt.legend()
plt.yticks([])
plt.show()

# %%
###Display BACE histogram
dataset_file= "./enamineSubset10KGroundTruth.csv"
train_dataset_file= "./bace.csv"

dataset = load_from_disk(dataset_file)
train_dataset = load_from_disk(train_dataset_file)

baces = np.array(dataset["bace"])
pIC50s = np.array(train_dataset["pIC50"])

n, bins, patches = plt.hist(baces, 50, facecolor='green', alpha=0.5, label="REAL", density=True)
n, bins, patches = plt.hist(pIC50s, 50, facecolor='blue', alpha=0.5, label="TRAIN", density=True)

plt.xlabel('Ground truth predicted pIC50')
plt.ylabel('Number of compounds')
plt.title(r'Histogram of predicted BACE Affinities')
plt.grid(True)
plt.legend()
plt.yticks([])
plt.show()

# %%
###Display BACE histogram
dataset_file= "./enamineSubset10KGroundTruth_3.csv"
#train_dataset_file= "./bace.csv"
train_dataset_file= "./enamineSubset10KGroundTruth_2.csv"
hundredK_file = "./enamineSubset10KGroundTruth.csv"
fourth = "./enamineSubset10KGroundTruth_4.csv"

dataset10 = load_from_disk(dataset_file)
dataset100 = load_from_disk(hundredK_file)
train_dataset = load_from_disk(train_dataset_file)
fourth_dataset = load_from_disk(fourth)

baces10 = np.array(dataset10["bace"])
baces100 = np.array(dataset100["bace"])
#pIC50s = np.array(train_dataset["pIC50"])
pIC50s = np.array(train_dataset["bace"])
fourth_bace = np.array(fourth_dataset["bace"])

plt.hist(baces10, 50, facecolor='green', alpha=0.5, label="10K Enamine Subset 3", density=True)
plt.hist(baces100, 50, facecolor='red', alpha=0.5, label="100K Enamine Subset 1", density=True)
plt.hist(pIC50s, 50, facecolor='blue', alpha=0.5, label="10K Enamine Subset 2", density=True)
plt.hist(fourth_bace, 50, facecolor='orange', alpha=.5, label="10K Enamine Subset 4", density=True)


plt.xlabel('BACE pIC50s')
plt.ylabel('Number of compounds')
plt.title(r'Training and ground truth model predicted BACE Affinities')
plt.grid(True)
plt.legend()
plt.yticks([])
plt.show()
